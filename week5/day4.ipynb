# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
tests[0:5]
# Out:
# [TestQuestion(question='Who won the prestigious IIOTY award in 2023?', keywords=['Maxine', 'Thompson', 'IIOTY'], reference_answer='Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.', category='direct_fact'),
#  TestQuestion(question='When was Insurellm founded?', keywords=['2015', 'founded'], reference_answer='Insurellm was founded in 2015.', category='direct_fact'),
#  TestQuestion(question='Who founded Insurellm?', keywords=['Avery', 'Lancaster'], reference_answer='Avery Lancaster founded Insurellm in 2015.', category='direct_fact'),
#  TestQuestion(question='How many employees does Insurellm currently have?', keywords=['32', 'employees'], reference_answer='Insurellm currently operates with 32 employees as of 2025.', category='direct_fact'),
#  TestQuestion(question="What was Insurellm's first product?", keywords=['Markellm', 'first'], reference_answer="Insurellm's first product was Markellm, the marketplace connecting consumers with insurance providers.", category='direct_fact')]

# %%
example = tests[0]
print(example.question)
print(example.keywords)
print(example.reference_answer)
print(example.category)
# Out:
# Who won the prestigious IIOTY award in 2023?
# ['Maxine', 'Thompson', 'IIOTY']
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# direct_fact

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
import os
os.environ["OPENAI_API_KEY"] = "anything"  # or your LiteLLM master key
os.environ["OPENAI_API_BASE"] = "http://localhost:4000/v1"

#  run ollama model in background
# also run "litellm --model ollama/llama3.1:8b --api_base http://localhost:11434 --port 4000" in background

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 evaluate_retrieval(example)
#
# File ~/Desktop/LLM_Enigneering/week5/evaluation/eval.py:93, in evaluate_retrieval(test, k)
#      86 keyword_lower = keyword.lower()
#      88 relevances = [
#      89     1 if keyword_lower in doc.page_content.lower() else 0
#      90     for doc in retrieved_docs[:k]
#      91 ]
# ---> 93 dcg = calculate_dcg(relevances, k)
#      94 ideal = sorted(relevances, reverse=True)
#      95 idcg = calculate_dcg(ideal, k)
#
# File ~/Desktop/LLM_Enigneering/week5/RAG/answer.py:65, in fetch_context(question)
#      63 if history is None:
#      64     history = []
# ---> 65 question = str(question)
#      66 prior = "\n".join(
#      67     str(m["content"])
#      68     for m in history
#      69     if isinstance(m, dict) and "content" in m
#      70 )
#      71 if prior:
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_core/retrievers.py:222, in BaseRetriever.invoke(self, input, config, **kwargs)
#     220 kwargs_ = kwargs if self._expects_other_args else {}
#     221 if self._new_arg_supported:
# --> 222     result = self._get_relevant_documents(
#     223         input, run_manager=run_manager, **kwargs_
#     224     )
#     225 else:
#     226     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1045, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1043 kwargs_ = self.search_kwargs | kwargs
#    1044 if self.search_type == "similarity":
# -> 1045     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1046 elif self.search_type == "similarity_score_threshold":
#    1047     docs_and_similarities = (
#    1048         self.vectorstore.similarity_search_with_relevance_scores(
#    1049             query, **kwargs_
#    1050         )
#    1051     )
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:748, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     730 def similarity_search(
#     731     self,
#     732     query: str,
#    (...)    735     **kwargs: Any,
#     736 ) -> list[Document]:
#     737     """Run similarity search with Chroma.
#     738
#     739     Args:
#    (...)    746         List of documents most similar to the query text.
#     747     """
# --> 748     docs_and_scores = self.similarity_search_with_score(
#     749         query,
#     750         k,
#     751         filter=filter,
#     752         **kwargs,
#     753     )
#     754     return [doc for doc, _ in docs_and_scores]
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:849, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     847 else:
#     848     query_embedding = self._embedding_function.embed_query(query)
# --> 849     results = self.__query_collection(
#     850         query_embeddings=[query_embedding],
#     851         n_results=k,
#     852         where=filter,
#     853         where_document=where_document,
#     854         **kwargs,
#     855     )
#     857 return _results_to_docs_and_scores(results)
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_core/utils/utils.py:51, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      45     msg = (
#      46         "Exactly one argument in each of the following"
#      47         " groups must be defined:"
#      48         f" {', '.join(invalid_group_names)}"
#      49     )
#      50     raise ValueError(msg)
# ---> 51 return func(*args, **kwargs)
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:477, in Chroma.__query_collection(self, query_texts, query_embeddings, n_results, where, where_document, **kwargs)
#     449 @xor_args(("query_texts", "query_embeddings"))
#     450 def __query_collection(
#     451     self,
#    (...)    457     **kwargs: Any,
#     458 ) -> list[Document] | chromadb.QueryResult:
#     459     """Query the chroma collection.
#     460
#     461     Args:
#    (...)    475     See more: https://docs.trychroma.com/reference/py-collection#query
#     476     """
# --> 477     return self._collection.query(
#     478         query_texts=query_texts,
#     479         query_embeddings=query_embeddings,  # type: ignore[arg-type]
#     480         n_results=n_results,
#     481         where=where,  # type: ignore[arg-type]
#     482         where_document=where_document,  # type: ignore[arg-type]
#     483         **kwargs,
#     484     )
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/chromadb/api/models/Collection.py:265, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     215 """Query for the K nearest neighbor records in the collection.
#     216
#     217 This is a batch query API. Multiple queries can be performed at once
#    (...)    250     ValueError: If multiple query input types are provided.
#     251 """
#     253 query_request = self._validate_and_prepare_query_request(
#     254     query_embeddings=query_embeddings,
#     255     query_texts=query_texts,
#    (...)    262     include=include,
#     263 )
# --> 265 query_results = self._client._query(
#     266     collection_id=self.id,
#     267     ids=query_request["ids"],
#     268     query_embeddings=query_request["embeddings"],
#     269     n_results=query_request["n_results"],
#     270     where=query_request["where"],
#     271     where_document=query_request["where_document"],
#     272     include=query_request["include"],
#     273     tenant=self.tenant,
#     274     database=self.database,
#     275 )
#     277 return self._transform_query_response(
#     278     response=query_results, include=query_request["include"]
#     279 )
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/chromadb/api/rust.py:582, in RustBindingsAPI._query(self, collection_id, query_embeddings, ids, n_results, where, where_document, include, tenant, database)
#     566 filtered_ids_amount = len(ids) if ids else 0
#     567 self.product_telemetry_client.capture(
#     568     CollectionQueryEvent(
#     569         collection_uuid=str(collection_id),
#    (...)    579     )
#     580 )
# --> 582 rust_response = self.bindings.query(
#     583     str(collection_id),
#     584     ids,
#     585     query_embeddings,
#     586     n_results,
#     587     json.dumps(where) if where else None,
#     588     json.dumps(where_document) if where_document else None,
#     589     include,
#     590     tenant,
#     591     database,
#     592 )
#     594 return QueryResult(
#     595     ids=rust_response.ids,
#     596     embeddings=rust_response.embeddings,
#    (...)    602     distances=rust_response.distances,
#     603 )
#
# NotFoundError: Error getting collection: Collection [ce201bb8-8122-46de-ad3e-2565c1789712] does not exist.

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File ~/Desktop/LLM_Enigneering/week5/evaluation/eval.py:128, in evaluate_answer(test)
#     122 def evaluate_answer(test: TestQuestion) -> tuple[AnswerEval, str, list]:
#     123     generated_answer, retrieved_docs = answer_question(test.question)
#     125     judge_messages = [
#     126         {
#     127             "role": "system",
# --> 128             "content": "You are an expert evaluator. Score strictly and fairly.",
#     129         },
#     130         {
#     131             "role": "user",
#     132             "content": f"""
#     133 Question:
#     134 {test.question}
#     135
#     136 Generated Answer:
#     137 {generated_answer}
#     138
#     139 Reference Answer:
#     140 {test.reference_answer}
#     141
#     142 Evaluate:
#     143 - Accuracy (1-5)
#     144 - Completeness (1-5)
#     145 - Relevance (1-5)
#     146 - Provide concise feedback
#     147 """,
#     148         },
#     149     ]
#     151     judge_response = completion(
#     152         messages=judge_messages,
#     153         response_format=AnswerEval,
#     154         max_retries=2,
#     155         **_judge_completion_kwargs(),
#     156     )
#     158     answer_eval = AnswerEval.model_validate_json(
#     159         judge_response.choices[0].message.content
#     160     )
#
# File ~/Desktop/LLM_Enigneering/week5/RAG/answer.py:85, in answer_question(question, history)
#      82 system_prompt = SYSTEM_PROMPT.format(context=context)
#      84 messages = [SystemMessage(content=system_prompt)]
# ---> 85 # filter out any SystemMessages from history to avoid overwriting context
#      86 messages.extend(convert_to_messages(history))
#      87 messages.append(HumanMessage(content=question))
#
# File ~/Desktop/LLM_Enigneering/week5/RAG/answer.py:65, in fetch_context(question)
#      63 if history is None:
#      64     history = []
# ---> 65 question = str(question)
#      66 prior = "\n".join(
#      67     str(m["content"])
#      68     for m in history
#      69     if isinstance(m, dict) and "content" in m
#      70 )
#      71 if prior:
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_core/retrievers.py:222, in BaseRetriever.invoke(self, input, config, **kwargs)
#     220 kwargs_ = kwargs if self._expects_other_args else {}
#     221 if self._new_arg_supported:
# --> 222     result = self._get_relevant_documents(
#     223         input, run_manager=run_manager, **kwargs_
#     224     )
#     225 else:
#     226     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:1045, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1043 kwargs_ = self.search_kwargs | kwargs
#    1044 if self.search_type == "similarity":
# -> 1045     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1046 elif self.search_type == "similarity_score_threshold":
#    1047     docs_and_similarities = (
#    1048         self.vectorstore.similarity_search_with_relevance_scores(
#    1049             query, **kwargs_
#    1050         )
#    1051     )
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:748, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     730 def similarity_search(
#     731     self,
#     732     query: str,
#    (...)    735     **kwargs: Any,
#     736 ) -> list[Document]:
#     737     """Run similarity search with Chroma.
#     738
#     739     Args:
#    (...)    746         List of documents most similar to the query text.
#     747     """
# --> 748     docs_and_scores = self.similarity_search_with_score(
#     749         query,
#     750         k,
#     751         filter=filter,
#     752         **kwargs,
#     753     )
#     754     return [doc for doc, _ in docs_and_scores]
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:849, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     847 else:
#     848     query_embedding = self._embedding_function.embed_query(query)
# --> 849     results = self.__query_collection(
#     850         query_embeddings=[query_embedding],
#     851         n_results=k,
#     852         where=filter,
#     853         where_document=where_document,
#     854         **kwargs,
#     855     )
#     857 return _results_to_docs_and_scores(results)
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_core/utils/utils.py:51, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      45     msg = (
#      46         "Exactly one argument in each of the following"
#      47         " groups must be defined:"
#      48         f" {', '.join(invalid_group_names)}"
#      49     )
#      50     raise ValueError(msg)
# ---> 51 return func(*args, **kwargs)
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py:477, in Chroma.__query_collection(self, query_texts, query_embeddings, n_results, where, where_document, **kwargs)
#     449 @xor_args(("query_texts", "query_embeddings"))
#     450 def __query_collection(
#     451     self,
#    (...)    457     **kwargs: Any,
#     458 ) -> list[Document] | chromadb.QueryResult:
#     459     """Query the chroma collection.
#     460
#     461     Args:
#    (...)    475     See more: https://docs.trychroma.com/reference/py-collection#query
#     476     """
# --> 477     return self._collection.query(
#     478         query_texts=query_texts,
#     479         query_embeddings=query_embeddings,  # type: ignore[arg-type]
#     480         n_results=n_results,
#     481         where=where,  # type: ignore[arg-type]
#     482         where_document=where_document,  # type: ignore[arg-type]
#     483         **kwargs,
#     484     )
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/chromadb/api/models/Collection.py:265, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     215 """Query for the K nearest neighbor records in the collection.
#     216
#     217 This is a batch query API. Multiple queries can be performed at once
#    (...)    250     ValueError: If multiple query input types are provided.
#     251 """
#     253 query_request = self._validate_and_prepare_query_request(
#     254     query_embeddings=query_embeddings,
#     255     query_texts=query_texts,
#    (...)    262     include=include,
#     263 )
# --> 265 query_results = self._client._query(
#     266     collection_id=self.id,
#     267     ids=query_request["ids"],
#     268     query_embeddings=query_request["embeddings"],
#     269     n_results=query_request["n_results"],
#     270     where=query_request["where"],
#     271     where_document=query_request["where_document"],
#     272     include=query_request["include"],
#     273     tenant=self.tenant,
#     274     database=self.database,
#     275 )
#     277 return self._transform_query_response(
#     278     response=query_results, include=query_request["include"]
#     279 )
#
# File ~/Desktop/LLM_Enigneering/.venv/lib/python3.12/site-packages/chromadb/api/rust.py:582, in RustBindingsAPI._query(self, collection_id, query_embeddings, ids, n_results, where, where_document, include, tenant, database)
#     566 filtered_ids_amount = len(ids) if ids else 0
#     567 self.product_telemetry_client.capture(
#     568     CollectionQueryEvent(
#     569         collection_uuid=str(collection_id),
#    (...)    579     )
#     580 )
# --> 582 rust_response = self.bindings.query(
#     583     str(collection_id),
#     584     ids,
#     585     query_embeddings,
#     586     n_results,
#     587     json.dumps(where) if where else None,
#     588     json.dumps(where_document) if where_document else None,
#     589     include,
#     590     tenant,
#     591     database,
#     592 )
#     594 return QueryResult(
#     595     ids=rust_response.ids,
#     596     embeddings=rust_response.embeddings,
#    (...)    602     distances=rust_response.distances,
#     603 )
#
# NotFoundError: Error getting collection: Collection [ce201bb8-8122-46de-ad3e-2565c1789712] does not exist.

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The generated answer contains a small error in the name of the award, it should be IIOTY (Insurellm Innovator of the Year), not IIOTY 2023 (Insurellm Innovator of the Year). However, it correctly identifies Maxine as the winner. The reference answer does not provide any additional information about the award; it only states the name and the year it was won.
# 5.0
# 4.0
# 5.0
